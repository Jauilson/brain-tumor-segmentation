# %% [markdown]
# Carregando o dataset Brain
#
# https://www.med.upenn.edu/sbia/brats2019/data.html

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.chdir("/content/gdrive/My Drive/databrain")
# Out:
# Mounted at /content/gdrive

# %%
# Listar arquivos na pasta imagesTr
import os
os.chdir("/content/gdrive/My Drive/databrain/imagesTr")
files_imagesTr = os.listdir()
print("Arquivos na pasta imagesTr:")
print(files_imagesTr)

# Listar arquivos na pasta imagesTs
os.chdir("/content/gdrive/My Drive/databrain/imagesTs")
files_imagesTs = os.listdir()
print("\nArquivos na pasta imagesTs:")
print(files_imagesTs)

# Listar arquivos na pasta labelsTr
os.chdir("/content/gdrive/My Drive/databrain/labelsTr")
files_labelsTr = os.listdir()
print("\nArquivos na pasta labelsTr:")
print(files_labelsTr)
# Out:
# Arquivos na pasta imagesTr:
# ['BRATS_001.nii.gz', 'BRATS_002.nii.gz', 'BRATS_003.nii.gz', 'BRATS_004.nii.gz', 'BRATS_005.nii.gz', 'BRATS_006.nii.gz', 'BRATS_007.nii.gz', 'BRATS_008.nii.gz', 'BRATS_009.nii.gz', 'BRATS_010.nii.gz', 'BRATS_011.nii.gz', 'BRATS_012.nii.gz', 'BRATS_013.nii.gz', 'BRATS_014.nii.gz', 'BRATS_015.nii.gz', 'BRATS_016.nii.gz', 'BRATS_017.nii.gz', 'BRATS_018.nii.gz', 'BRATS_019.nii.gz', 'BRATS_020.nii.gz', 'BRATS_021.nii.gz', 'BRATS_022.nii.gz', 'BRATS_023.nii.gz', 'BRATS_024.nii.gz', 'BRATS_025.nii.gz', 'BRATS_026.nii.gz', 'BRATS_027.nii.gz', 'BRATS_028.nii.gz', 'BRATS_029.nii.gz', 'BRATS_030.nii.gz', 'BRATS_031.nii.gz', 'BRATS_032.nii.gz', 'BRATS_033.nii.gz', 'BRATS_034.nii.gz', 'BRATS_035.nii.gz', 'BRATS_036.nii.gz', 'BRATS_037.nii.gz', 'BRATS_038.nii.gz', 'BRATS_039.nii.gz', 'BRATS_040.nii.gz', 'BRATS_041.nii.gz', 'BRATS_042.nii.gz', 'BRATS_043.nii.gz', 'BRATS_044.nii.gz', 'BRATS_045.nii.gz', 'BRATS_046.nii.gz', 'BRATS_047.nii.gz', 'BRATS_048.nii.gz', 'BRATS_049.nii.gz', 'BRATS_050.nii.gz', 'BRATS_051.nii.gz', 'BRATS_052.nii.gz', 'BRATS_053.nii.gz', 'BRATS_054.nii.gz', 'BRATS_055.nii.gz', 'BRATS_056.nii.gz', 'BRATS_057.nii.gz', 'BRATS_058.nii.gz', 'BRATS_059.nii.gz', 'BRATS_060.nii.gz', 'BRATS_061.nii.gz', 'BRATS_062.nii.gz', 'BRATS_063.nii.gz', 'BRATS_064.nii.gz', 'BRATS_065.nii.gz', 'BRATS_066.nii.gz', 'BRATS_067.nii.gz', 'BRATS_068.nii.gz', 'BRATS_069.nii.gz', 'BRATS_070.nii.gz', 'BRATS_071.nii.gz', 'BRATS_072.nii.gz', 'BRATS_073.nii.gz', 'BRATS_074.nii.gz', 'BRATS_075.nii.gz', 'BRATS_076.nii.gz', 'BRATS_077.nii.gz', 'BRATS_078.nii.gz', 'BRATS_079.nii.gz', 'BRATS_080.nii.gz', 'BRATS_081.nii.gz', 'BRATS_082.nii.gz', 'BRATS_083.nii.gz', 'BRATS_084.nii.gz', 'BRATS_085.nii.gz', 'BRATS_086.nii.gz', 'BRATS_087.nii.gz', 'BRATS_088.nii.gz', 'BRATS_089.nii.gz', 'BRATS_090.nii.gz', 'BRATS_091.nii.gz', 'BRATS_092.nii.gz', 'BRATS_093.nii.gz', 'BRATS_094.nii.gz', 'BRATS_095.nii.gz', 'BRATS_096.nii.gz', 'BRATS_097.nii.gz', 'BRATS_098.nii.gz', 'BRATS_099.nii.gz', 'BRATS_100.nii.gz', 'BRATS_101.nii.gz', 'BRATS_102.nii.gz', 'BRATS_103.nii.gz', 'BRATS_104.nii.gz', 'BRATS_105.nii.gz', 'BRATS_106.nii.gz', 'BRATS_107.nii.gz', 'BRATS_108.nii.gz', 'BRATS_109.nii.gz', 'BRATS_110.nii.gz', 'BRATS_111.nii.gz', 'BRATS_112.nii.gz', 'BRATS_113.nii.gz', 'BRATS_114.nii.gz', 'BRATS_115.nii.gz', 'BRATS_116.nii.gz', 'BRATS_117.nii.gz', 'BRATS_118.nii.gz', 'BRATS_119.nii.gz', 'BRATS_120.nii.gz', 'BRATS_121.nii.gz', 'BRATS_122.nii.gz', 'BRATS_123.nii.gz', 'BRATS_124.nii.gz', 'BRATS_125.nii.gz', 'BRATS_126.nii.gz', 'BRATS_127.nii.gz', 'BRATS_128.nii.gz', 'BRATS_129.nii.gz', 'BRATS_130.nii.gz', 'BRATS_131.nii.gz', 'BRATS_132.nii.gz', 'BRATS_133.nii.gz', 'BRATS_134.nii.gz', 'BRATS_135.nii.gz', 'BRATS_136.nii.gz', 'BRATS_137.nii.gz', 'BRATS_138.nii.gz', 'BRATS_139.nii.gz', 'BRATS_140.nii.gz', 'BRATS_141.nii.gz', 'BRATS_142.nii.gz', 'BRATS_143.nii.gz', 'BRATS_144.nii.gz', 'BRATS_145.nii.gz', 'BRATS_146.nii.gz', 'BRATS_147.nii.gz', 'BRATS_148.nii.gz', 'BRATS_149.nii.gz', 'BRATS_150.nii.gz', 'BRATS_151.nii.gz', 'BRATS_152.nii.gz', 'BRATS_153.nii.gz', 'BRATS_154.nii.gz', 'BRATS_155.nii.gz', 'BRATS_156.nii.gz', 'BRATS_157.nii.gz', 'BRATS_158.nii.gz', 'BRATS_159.nii.gz', 'BRATS_160.nii.gz', 'BRATS_161.nii.gz', 'BRATS_162.nii.gz', 'BRATS_163.nii.gz', 'BRATS_164.nii.gz', 'BRATS_165.nii.gz', 'BRATS_166.nii.gz', 'BRATS_167.nii.gz', 'BRATS_168.nii.gz', 'BRATS_169.nii.gz', 'BRATS_170.nii.gz', 'BRATS_171.nii.gz', 'BRATS_172.nii.gz', 'BRATS_173.nii.gz', 'BRATS_174.nii.gz', 'BRATS_175.nii.gz', 'BRATS_176.nii.gz', 'BRATS_177.nii.gz', 'BRATS_178.nii.gz', 'BRATS_179.nii.gz', 'BRATS_180.nii.gz', 'BRATS_181.nii.gz', 'BRATS_182.nii.gz', 'BRATS_183.nii.gz', 'BRATS_184.nii.gz', 'BRATS_185.nii.gz', 'BRATS_186.nii.gz', 'BRATS_187.nii.gz', 'BRATS_188.nii.gz', 'BRATS_189.nii.gz', 'BRATS_190.nii.gz', 'BRATS_191.nii.gz', 'BRATS_192.nii.gz', 'BRATS_193.nii.gz', 'BRATS_194.nii.gz', 'BRATS_195.nii.gz', 'BRATS_196.nii.gz', 'BRATS_197.nii.gz', 'BRATS_198.nii.gz', 'BRATS_199.nii.gz', 'BRATS_200.nii.gz', ...
#
# Arquivos na pasta imagesTs:
# ['BRATS_485.nii.gz', 'BRATS_486.nii.gz', '._BRATS_487.nii.gz', 'BRATS_487.nii.gz', '._BRATS_488.nii.gz', 'BRATS_488.nii.gz', 'BRATS_489.nii.gz', 'BRATS_490.nii.gz', '._BRATS_490.nii.gz', 'BRATS_491.nii.gz', 'BRATS_492.nii.gz', 'BRATS_493.nii.gz', '._BRATS_493.nii.gz', 'BRATS_494.nii.gz', '._BRATS_494.nii.gz', 'BRATS_495.nii.gz', '._BRATS_495.nii.gz', 'BRATS_496.nii.gz', 'BRATS_497.nii.gz', 'BRATS_498.nii.gz', 'BRATS_499.nii.gz', 'BRATS_500.nii.gz', '._BRATS_501.nii.gz', 'BRATS_501.nii.gz', 'BRATS_502.nii.gz', 'BRATS_503.nii.gz', 'BRATS_504.nii.gz', 'BRATS_505.nii.gz', 'BRATS_506.nii.gz', 'BRATS_507.nii.gz', 'BRATS_508.nii.gz', 'BRATS_509.nii.gz', 'BRATS_510.nii.gz', 'BRATS_511.nii.gz', '._BRATS_512.nii.gz', 'BRATS_512.nii.gz', 'BRATS_513.nii.gz', '._BRATS_514.nii.gz', 'BRATS_514.nii.gz', 'BRATS_515.nii.gz', 'BRATS_516.nii.gz', 'BRATS_517.nii.gz', 'BRATS_518.nii.gz', 'BRATS_519.nii.gz', 'BRATS_520.nii.gz', 'BRATS_521.nii.gz', 'BRATS_522.nii.gz', 'BRATS_523.nii.gz', 'BRATS_524.nii.gz', 'BRATS_525.nii.gz', 'BRATS_526.nii.gz', 'BRATS_527.nii.gz', 'BRATS_528.nii.gz', 'BRATS_529.nii.gz', 'BRATS_530.nii.gz', 'BRATS_531.nii.gz', 'BRATS_532.nii.gz', 'BRATS_533.nii.gz', 'BRATS_534.nii.gz', 'BRATS_535.nii.gz', 'BRATS_536.nii.gz', 'BRATS_537.nii.gz', 'BRATS_538.nii.gz', 'BRATS_539.nii.gz', 'BRATS_540.nii.gz', 'BRATS_541.nii.gz', 'BRATS_542.nii.gz', 'BRATS_543.nii.gz', 'BRATS_544.nii.gz', 'BRATS_545.nii.gz', 'BRATS_546.nii.gz', 'BRATS_547.nii.gz', 'BRATS_548.nii.gz', '._BRATS_548.nii.gz', 'BRATS_549.nii.gz', 'BRATS_550.nii.gz', 'BRATS_551.nii.gz', 'BRATS_552.nii.gz', 'BRATS_553.nii.gz', 'BRATS_554.nii.gz', 'BRATS_555.nii.gz', 'BRATS_556.nii.gz', 'BRATS_557.nii.gz', 'BRATS_558.nii.gz', 'BRATS_559.nii.gz', 'BRATS_560.nii.gz', 'BRATS_561.nii.gz', 'BRATS_562.nii.gz', 'BRATS_563.nii.gz', 'BRATS_564.nii.gz', 'BRATS_565.nii.gz', 'BRATS_566.nii.gz', 'BRATS_567.nii.gz', 'BRATS_568.nii.gz', 'BRATS_569.nii.gz', 'BRATS_570.nii.gz', 'BRATS_571.nii.gz', 'BRATS_572.nii.gz', 'BRATS_573.nii.gz', 'BRATS_574.nii.gz', 'BRATS_575.nii.gz', 'BRATS_576.nii.gz', 'BRATS_577.nii.gz', 'BRATS_578.nii.gz', 'BRATS_579.nii.gz', 'BRATS_580.nii.gz', 'BRATS_581.nii.gz', 'BRATS_582.nii.gz', 'BRATS_583.nii.gz', 'BRATS_584.nii.gz', 'BRATS_585.nii.gz', 'BRATS_586.nii.gz', 'BRATS_587.nii.gz', 'BRATS_588.nii.gz', 'BRATS_589.nii.gz', 'BRATS_590.nii.gz', 'BRATS_591.nii.gz', 'BRATS_592.nii.gz', 'BRATS_593.nii.gz', 'BRATS_594.nii.gz', 'BRATS_595.nii.gz', 'BRATS_596.nii.gz', 'BRATS_597.nii.gz', 'BRATS_598.nii.gz', 'BRATS_599.nii.gz', 'BRATS_600.nii.gz', 'BRATS_601.nii.gz', 'BRATS_602.nii.gz', 'BRATS_603.nii.gz', 'BRATS_604.nii.gz', 'BRATS_605.nii.gz', 'BRATS_606.nii.gz', 'BRATS_607.nii.gz', 'BRATS_608.nii.gz', 'BRATS_609.nii.gz', 'BRATS_610.nii.gz', '._BRATS_610.nii.gz', '._BRATS_611.nii.gz', 'BRATS_611.nii.gz', 'BRATS_612.nii.gz', 'BRATS_613.nii.gz', 'BRATS_614.nii.gz', 'BRATS_615.nii.gz', 'BRATS_616.nii.gz', 'BRATS_617.nii.gz', 'BRATS_618.nii.gz', 'BRATS_619.nii.gz', 'BRATS_620.nii.gz', 'BRATS_621.nii.gz', 'BRATS_622.nii.gz', 'BRATS_623.nii.gz', 'BRATS_624.nii.gz', 'BRATS_625.nii.gz', 'BRATS_626.nii.gz', 'BRATS_627.nii.gz', 'BRATS_628.nii.gz', 'BRATS_629.nii.gz', 'BRATS_630.nii.gz', 'BRATS_631.nii.gz', 'BRATS_632.nii.gz', 'BRATS_633.nii.gz', 'BRATS_634.nii.gz', 'BRATS_635.nii.gz', 'BRATS_636.nii.gz', 'BRATS_637.nii.gz', 'BRATS_638.nii.gz', 'BRATS_639.nii.gz', 'BRATS_640.nii.gz', 'BRATS_641.nii.gz', 'BRATS_642.nii.gz', 'BRATS_643.nii.gz', 'BRATS_644.nii.gz', 'BRATS_645.nii.gz', 'BRATS_646.nii.gz', 'BRATS_647.nii.gz', 'BRATS_648.nii.gz', 'BRATS_649.nii.gz', 'BRATS_650.nii.gz', 'BRATS_651.nii.gz', 'BRATS_652.nii.gz', 'BRATS_653.nii.gz', 'BRATS_654.nii.gz', 'BRATS_655.nii.gz', 'BRATS_656.nii.gz', 'BRATS_657.nii.gz', 'BRATS_658.nii.gz', 'BRATS_659.nii.gz', 'BRATS_660.nii.gz', 'BRATS_661.nii.gz', '._BRATS_661.nii.gz', 'BRATS_662.nii.gz', 'BRATS_663.nii.gz', 'BRATS_664.nii.gz', 'BRATS_665.nii.gz', 'BRATS_666.nii.gz', 'BRATS_667.nii.gz', 'BRATS_668.nii.gz', 'BRATS_669.nii.gz', 'BRATS_670.ni ...
#
# Arquivos na pasta labelsTr:
# ['BRATS_003.nii.gz', 'BRATS_004.nii.gz', 'BRATS_001.nii.gz', 'BRATS_002.nii.gz', 'BRATS_010.nii.gz', 'BRATS_008.nii.gz', 'BRATS_007.nii.gz', 'BRATS_006.nii.gz', 'BRATS_005.nii.gz', 'BRATS_009.nii.gz', 'BRATS_014.nii.gz', 'BRATS_012.nii.gz', 'BRATS_011.nii.gz', 'BRATS_013.nii.gz', 'BRATS_015.nii.gz', 'BRATS_021.nii.gz', 'BRATS_018.nii.gz', 'BRATS_019.nii.gz', 'BRATS_017.nii.gz', 'BRATS_016.nii.gz', 'BRATS_020.nii.gz', 'BRATS_024.nii.gz', 'BRATS_022.nii.gz', 'BRATS_026.nii.gz', 'BRATS_027.nii.gz', 'BRATS_023.nii.gz', 'BRATS_025.nii.gz', 'BRATS_029.nii.gz', 'BRATS_033.nii.gz', 'BRATS_030.nii.gz', 'BRATS_031.nii.gz', 'BRATS_032.nii.gz', 'BRATS_028.nii.gz', 'BRATS_035.nii.gz', 'BRATS_037.nii.gz', 'BRATS_036.nii.gz', 'BRATS_038.nii.gz', 'BRATS_034.nii.gz', 'BRATS_040.nii.gz', 'BRATS_043.nii.gz', 'BRATS_041.nii.gz', 'BRATS_042.nii.gz', 'BRATS_039.nii.gz', 'BRATS_048.nii.gz', 'BRATS_046.nii.gz', 'BRATS_044.nii.gz', 'BRATS_047.nii.gz', 'BRATS_045.nii.gz', 'BRATS_054.nii.gz', 'BRATS_051.nii.gz', 'BRATS_052.nii.gz', 'BRATS_050.nii.gz', 'BRATS_049.nii.gz', 'BRATS_053.nii.gz', 'BRATS_056.nii.gz', 'BRATS_057.nii.gz', 'BRATS_058.nii.gz', 'BRATS_060.nii.gz', 'BRATS_055.nii.gz', 'BRATS_059.nii.gz', 'BRATS_061.nii.gz', 'BRATS_062.nii.gz', 'BRATS_063.nii.gz', 'BRATS_064.nii.gz', 'BRATS_067.nii.gz', 'BRATS_066.nii.gz', 'BRATS_068.nii.gz', 'BRATS_070.nii.gz', 'BRATS_065.nii.gz', 'BRATS_069.nii.gz', 'BRATS_076.nii.gz', 'BRATS_071.nii.gz', 'BRATS_072.nii.gz', 'BRATS_074.nii.gz', 'BRATS_075.nii.gz', 'BRATS_073.nii.gz', 'BRATS_080.nii.gz', 'BRATS_079.nii.gz', 'BRATS_081.nii.gz', 'BRATS_077.nii.gz', 'BRATS_078.nii.gz', 'BRATS_085.nii.gz', 'BRATS_086.nii.gz', 'BRATS_084.nii.gz', 'BRATS_087.nii.gz', 'BRATS_082.nii.gz', 'BRATS_083.nii.gz', 'BRATS_088.nii.gz', 'BRATS_092.nii.gz', 'BRATS_090.nii.gz', 'BRATS_089.nii.gz', 'BRATS_091.nii.gz', 'BRATS_094.nii.gz', 'BRATS_097.nii.gz', 'BRATS_096.nii.gz', 'BRATS_095.nii.gz', 'BRATS_098.nii.gz', 'BRATS_093.nii.gz', 'BRATS_104.nii.gz', 'BRATS_103.nii.gz', 'BRATS_102.nii.gz', 'BRATS_100.nii.gz', 'BRATS_099.nii.gz', 'BRATS_101.nii.gz', 'BRATS_109.nii.gz', 'BRATS_106.nii.gz', 'BRATS_107.nii.gz', 'BRATS_108.nii.gz', 'BRATS_105.nii.gz', 'BRATS_111.nii.gz', 'BRATS_113.nii.gz', 'BRATS_114.nii.gz', 'BRATS_112.nii.gz', 'BRATS_110.nii.gz', 'BRATS_115.nii.gz', 'BRATS_120.nii.gz', 'BRATS_119.nii.gz', 'BRATS_116.nii.gz', 'BRATS_118.nii.gz', 'BRATS_117.nii.gz', 'BRATS_122.nii.gz', 'BRATS_121.nii.gz', 'BRATS_123.nii.gz', 'BRATS_126.nii.gz', 'BRATS_124.nii.gz', 'BRATS_125.nii.gz', 'BRATS_127.nii.gz', 'BRATS_131.nii.gz', 'BRATS_129.nii.gz', 'BRATS_130.nii.gz', 'BRATS_128.nii.gz', 'BRATS_136.nii.gz', 'BRATS_134.nii.gz', 'BRATS_137.nii.gz', 'BRATS_135.nii.gz', 'BRATS_133.nii.gz', 'BRATS_132.nii.gz', 'BRATS_139.nii.gz', 'BRATS_138.nii.gz', 'BRATS_140.nii.gz', 'BRATS_142.nii.gz', 'BRATS_143.nii.gz', 'BRATS_141.nii.gz', 'BRATS_145.nii.gz', 'BRATS_147.nii.gz', 'BRATS_148.nii.gz', 'BRATS_146.nii.gz', 'BRATS_144.nii.gz', 'BRATS_149.nii.gz', 'BRATS_150.nii.gz', 'BRATS_154.nii.gz', 'BRATS_151.nii.gz', 'BRATS_153.nii.gz', 'BRATS_152.nii.gz', 'BRATS_157.nii.gz', 'BRATS_158.nii.gz', 'BRATS_155.nii.gz', 'BRATS_160.nii.gz', 'BRATS_156.nii.gz', 'BRATS_159.nii.gz', 'BRATS_161.nii.gz', 'BRATS_164.nii.gz', '._BRATS_166.nii.gz', 'BRATS_166.nii.gz', 'BRATS_163.nii.gz', 'BRATS_162.nii.gz', 'BRATS_165.nii.gz', 'BRATS_171.nii.gz', 'BRATS_170.nii.gz', 'BRATS_167.nii.gz', 'BRATS_172.nii.gz', 'BRATS_169.nii.gz', 'BRATS_168.nii.gz', 'BRATS_175.nii.gz', 'BRATS_176.nii.gz', 'BRATS_174.nii.gz', 'BRATS_178.nii.gz', 'BRATS_177.nii.gz', 'BRATS_173.nii.gz', 'BRATS_184.nii.gz', 'BRATS_182.nii.gz', 'BRATS_180.nii.gz', 'BRATS_183.nii.gz', 'BRATS_179.nii.gz', 'BRATS_181.nii.gz', 'BRATS_190.nii.gz', 'BRATS_189.nii.gz', 'BRATS_187.nii.gz', 'BRATS_188.nii.gz', 'BRATS_186.nii.gz', 'BRATS_185.nii.gz', 'BRATS_195.nii.gz', 'BRATS_194.nii.gz', 'BRATS_191.nii.gz', 'BRATS_196.nii.gz', 'BRATS_192.nii.gz', 'BRATS_193.nii.gz', 'BRATS_197.nii.gz', 'BRATS_198.nii.gz', 'BRATS_201.nii.gz ...

# %% [markdown]
# Normaliza os valores dos pixels para que os dados fiquem na mesma escala
# ---Função para exibir as imagens

# %%
import nibabel as nib
import numpy as np

# Defina os caminhos para as pastas com imagens e rótulos
images_dir = "/content/gdrive/My Drive/databrain/imagesTr"
labels_dir = "/content/gdrive/My Drive/databrain/labelsTr"

# Loop através dos arquivos BRATS_001.nii.gz até BRATS_484.nii.gz
for i in range(1, 485):
    # Gere o nome do arquivo a partir do índice, com preenchimento de zero (por exemplo, BRATS_001.nii.gz)
    file_index = str(i).zfill(3)
    image_filename = f"{images_dir}/BRATS_{file_index}.nii.gz"
    label_filename = f"{labels_dir}/BRATS_{file_index}.nii.gz"

    # Carregue a imagem e o rótulo
    image = nib.load(image_filename).get_fdata()
    label = nib.load(label_filename).get_fdata()

    # Pré-processamento (normalização, redimensionamento, segmentação, etc.) aqui
    # Substitua esta parte pelo seu código de pré-processamento específico.

    # Exemplo: Normalização min-max
    min_value = np.min(image)
    max_value = np.max(image)
    normalized_image = (image - min_value) / (max_value - min_value)

    # Salve a imagem pré-processada se desejar
    preprocessed_image = nib.Nifti1Image(normalized_image, nib.load(image_filename).affine)
    output_filename = f"/content/gdrive/My Drive/databrain/preprocessed_images/BRATS_{file_index}_preprocessed.nii.gz"
    nib.save(preprocessed_image, output_filename)

    # Continue com o processamento ou análise dos dados conforme necessário

# %%
# !pip install tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras as keras


# Defina a arquitetura do modelo UNet
def unet_model(input_shape):
    inputs = keras.Input(shape=input_shape)

    # Codificador
    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    # Decodificador
    up4 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv3)
    up4 = layers.concatenate([up4, conv2], axis=-1)
    conv4 = layers.Conv2D(128, 3, activation='relu', padding='same')(up4)
    conv4 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv4)

    up5 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv4)
    up5 = layers.concatenate([up5, conv1], axis=-1)
    conv5 = layers.Conv2D(64, 3, activation='relu', padding='same')(up5)
    conv5 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv5)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv5)

    model = keras.Model(inputs, outputs)
    return model

# Crie uma instância do modelo
input_shape = (128, 128, 1)  # Ajuste o tamanho da imagem conforme necessário
model = unet_model(input_shape)

# Compile o modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Exiba o resumo do modelo
model.summary()

# %%
import tensorflow as tf
from tensorflow import keras

# Defina o modelo
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(100,)),
    keras.layers.Dense(10, activation='softmax')
])

# Compile o modelo
model.compile(optimizer='adam',  # Otimizador
              loss='categorical_crossentropy',  # Função de perda
              metrics=['accuracy'])  # Métricas para avaliação

# Para um modelo de classificação binária, você pode usar:
# loss='binary_crossentropy' e métricas=['accuracy']

# Para modelos de regressão, a função de perda e as métricas variam de acordo com o problema.

# Resumo do modelo
model.summary()

# %%
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np

# Defina a pasta com as imagens pré-processadas
preprocessed_dir = "/content/gdrive/My Drive/databrain/preprocessed_images"

# Lista de índices das imagens que você deseja exibir
indices_to_display = [1, 2, 3]  # Substitua pelos índices desejados

# Função para exibir imagens
def display_images(image_paths):
    for image_path in image_paths:
        image = nib.load(image_path).get_fdata()
        plt.figure(figsize=(6, 6))
        plt.imshow(image[:, :, 0], cmap='gray')  # Exibindo a primeira fatia da imagem 3D
        plt.title(f"Imagem: {image_path.split('/')[-1]}")
        plt.axis('off')
        plt.show()

# Crie a lista de caminhos para as imagens pré-processadas
image_paths = [f"{preprocessed_dir}/BRATS_{str(i).zfill(3)}_preprocessed.nii.gz" for i in indices_to_display]

# Exiba as imagens
display_images(image_paths)

# %%
# Listar arquivos na pasta labelsTr
os.chdir("/content/gdrive/My Drive/databrain/labelsTr")
files_labelsTr = os.listdir()
print("\nArquivos na pasta labelsTr:")
print(files_labelsTr)

# %%
import os
import nibabel as nib
import numpy as np

# Defina os caminhos para as pastas com imagens e rótulos
images_dir = "/content/gdrive/My Drive/databrain/imagesTr"
labels_dir = "/content/gdrive/My Drive/databrain/labelsTr"

# Lista para armazenar as imagens e rótulos
images = []
labels = []

# Loop através dos arquivos BRATS_001.nii.gz até BRATS_484.nii.gz
for i in range(1, 485):
    # Gere o nome do arquivo a partir do índice, com preenchimento de zero (por exemplo, BRATS_001.nii.gz)
    file_index = str(i).zfill(3)
    image_filename = f"{images_dir}/BRATS_{file_index}.nii.gz"
    label_filename = f"{labels_dir}/BRATS_{file_index}.nii.gz"

    # Carregue a imagem e o rótulo
    image = nib.load(image_filename).get_fdata()
    label = nib.load(label_filename).get_fdata()

    # Adicione a imagem e o rótulo à lista
    images.append(image)
    labels.append(label)

# Converta as listas em arrays numpy
images = np.array(images)
labels = np.array(labels)

# Agora você pode usar as variáveis 'images' e 'labels' para treinar e validar seu modelo.

# %%
historico = model.fit(preprocessed_image, labelsTr, epochs=10, validation_data=(imageTs, None))
